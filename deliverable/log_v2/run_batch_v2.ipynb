# %% [markdown]
# # V2 batch simulation runner -- rich JSONL logs
#
# Each deck cell runs the full matrix for that **P1 deck**:
# 5 P1 agents x 5 P2 agents x 9 P2 decks x 20 games = **4,500 games** (~1-2 h),
# writing one `.jsonl` per game into `log_v2/<agent1>_<deck1>/` plus a `summary.csv`.
#
# * **Resumable**: finished games are skipped, so you can interrupt the kernel and re-run a cell.
# * Run cells in any order; each deck is independent. All 9 cells = 40,500 games (~10-15 h, ~6 GB).
# * Log format: see the docstring of `sim_rich.py` (game_meta / mulligan / decision / game_end records; per-decision legal options, chosen action, full both-sides state snapshot, attributed events).
# * **Decks are the restored 30-card lists from `decks_v2.py`** (all implemented cards put back; Zoo padded with a 2nd Abusive Sergeant + Crazed Alchemist for the unimplemented Dark Peddler). Not directly comparable to the old `log/` runs.
# * `search_secs` in the records is for debugging only -- do **not** use it as a behavioral metric.

# %%
import os, sys
sys.path.insert(0, os.path.abspath("."))   # notebook lives in log_v2/, next to run_batch_matrix_v2.py
import run_batch_matrix_v2 as v2
print("decks :", ", ".join(v2.DECK_LIST))
print("agents:", ", ".join(v2.AGENT1_FUNCS))
print("games per matchup:", v2.NUM_GAMES, " search depth=%d width=%d"
      % (v2.sim.SEARCH_MAX_DEPTH, v2.sim.SEARCH_MAX_WIDTH))
print("output ->", v2.DEFAULT_LOG_ROOT)
# Out:
# decks : MiraclePirateRogue, ZooDiscardWarlock, RenoKazakusDragonPriest, MidrangeSecretHunter, MidrangeBuffPaladin, MurlocDruid, MidrangeJadeShaman, AggroPirateWarrior, RenoKazakusMage
# agents: aggro, control, fatigue, midrange, ramp
# games per matchup: 20  search depth=10 width=14
# output -> d:\test\log_v2

# %% [markdown]
# ## P1 deck: MiraclePirateRogue

# %%
v2.run_deck1_batch("MiraclePirateRogue")
# Out:
# ...
# V2 BATCH  deck1=MiraclePirateRogue  (4500 games: 5 P1 agents x 5 P2 agents x 9 decks x 20)
#   search depth=10 width=14   logs -> d:\test\log_v2
# ...
#
# ### aggro_MiraclePirateRogue  (900 games)
#   aggro    vs aggro   /MiraclePirateRogue       P1= 0 P2= 0 D=0 E=0 S=20  [   20/4500   0%]  eta   0.0 min  (0.0s)
#   aggro    vs aggro   /ZooDiscardWarlock        P1= 0 P2= 0 D=0 E=0 S=20  [   40/4500   1%]  eta   0.0 min  (0.0s)
#   aggro    vs aggro   /RenoKazakusDragonPriest  P1= 0 P2= 0 D=0 E=0 S=20  [   60/4500   1%]  eta   0.0 min  (0.0s)
#   aggro    vs aggro   /MidrangeSecretHunter     P1= 0 P2= 0 D=0 E=0 S=20  [   80/4500   2%]  eta   0.0 min  (0.0s)
#   aggro    vs aggro   /MidrangeBuffPaladin      P1= 0 P2= 0 D=0 E=0 S=20  [  100/4500   2%]  eta   0.0 min  (0.0s)
#   aggro    vs aggro   /MurlocDruid              P1= 0 P2= 0 D=0 E=0 S=20  [  120/4500   3%]  eta   0.0 min  (0.0s)
# ...

# %% [markdown]
# ## P1 deck: ZooDiscardWarlock

# %%
v2.run_deck1_batch("ZooDiscardWarlock")
# Out:
# ...
# V2 BATCH  deck1=ZooDiscardWarlock  (4500 games: 5 P1 agents x 5 P2 agents x 9 decks x 20)
#   search depth=10 width=14   logs -> d:\test\log_v2
# ...
#
# ### aggro_ZooDiscardWarlock  (900 games)
#   aggro    vs aggro   /MiraclePirateRogue       P1= 0 P2= 0 D=0 E=0 S=20  [   20/4500   0%]  eta   0.0 min  (0.0s)
#   aggro    vs aggro   /ZooDiscardWarlock        P1= 0 P2= 0 D=0 E=0 S=20  [   40/4500   1%]  eta   0.0 min  (0.0s)
#   aggro    vs aggro   /RenoKazakusDragonPriest  P1= 0 P2= 0 D=0 E=0 S=20  [   60/4500   1%]  eta   0.0 min  (0.0s)
#   aggro    vs aggro   /MidrangeSecretHunter     P1= 0 P2= 0 D=0 E=0 S=20  [   80/4500   2%]  eta   0.0 min  (0.0s)
#   aggro    vs aggro   /MidrangeBuffPaladin      P1= 0 P2= 0 D=0 E=0 S=20  [  100/4500   2%]  eta   0.0 min  (0.0s)
#   aggro    vs aggro   /MurlocDruid              P1= 0 P2= 0 D=0 E=0 S=20  [  120/4500   3%]  eta   0.0 min  (0.0s)
# ...

# %% [markdown]
# ## P1 deck: RenoKazakusDragonPriest

# %%
v2.run_deck1_batch("RenoKazakusDragonPriest")
# Out:
# ...
# V2 BATCH  deck1=RenoKazakusDragonPriest  (4500 games: 5 P1 agents x 5 P2 agents x 9 decks x 20)
#   search depth=10 width=14   logs -> d:\test\log_v2
# ...
#
# ### aggro_RenoKazakusDragonPriest  (900 games)
#   aggro    vs aggro   /MiraclePirateRogue       P1= 0 P2= 0 D=0 E=0 S=20  [   20/4500   0%]  eta   0.0 min  (0.0s)
#   aggro    vs aggro   /ZooDiscardWarlock        P1= 0 P2= 0 D=0 E=0 S=20  [   40/4500   1%]  eta   0.0 min  (0.0s)
#   aggro    vs aggro   /RenoKazakusDragonPriest  P1= 0 P2= 0 D=0 E=0 S=20  [   60/4500   1%]  eta   0.0 min  (0.0s)
#   aggro    vs aggro   /MidrangeSecretHunter     P1= 0 P2= 0 D=0 E=0 S=20  [   80/4500   2%]  eta   0.0 min  (0.0s)
#   aggro    vs aggro   /MidrangeBuffPaladin      P1= 0 P2= 0 D=0 E=0 S=20  [  100/4500   2%]  eta   0.0 min  (0.0s)
#   aggro    vs aggro   /MurlocDruid              P1= 0 P2= 0 D=0 E=0 S=20  [  120/4500   3%]  eta   0.0 min  (0.0s)
# ...

# %% [markdown]
# ## P1 deck: MidrangeSecretHunter

# %%
v2.run_deck1_batch("MidrangeSecretHunter")
# Out:
# ...
# V2 BATCH  deck1=MidrangeSecretHunter  (4500 games: 5 P1 agents x 5 P2 agents x 9 decks x 20)
#   search depth=10 width=14   logs -> d:\test\log_v2
# ...
#
# ### aggro_MidrangeSecretHunter  (900 games)
#   aggro    vs aggro   /MiraclePirateRogue       P1= 0 P2= 0 D=0 E=0 S=20  [   20/4500   0%]  eta   0.0 min  (0.0s)
#   aggro    vs aggro   /ZooDiscardWarlock        P1= 0 P2= 0 D=0 E=0 S=20  [   40/4500   1%]  eta   0.0 min  (0.0s)
#   aggro    vs aggro   /RenoKazakusDragonPriest  P1= 0 P2= 0 D=0 E=0 S=20  [   60/4500   1%]  eta   0.0 min  (0.0s)
#   aggro    vs aggro   /MidrangeSecretHunter     P1= 0 P2= 0 D=0 E=0 S=20  [   80/4500   2%]  eta   0.0 min  (0.0s)
#   aggro    vs aggro   /MidrangeBuffPaladin      P1= 0 P2= 0 D=0 E=0 S=20  [  100/4500   2%]  eta   0.0 min  (0.0s)
#   aggro    vs aggro   /MurlocDruid              P1= 0 P2= 0 D=0 E=0 S=20  [  120/4500   3%]  eta   0.0 min  (0.0s)
# ...

# %% [markdown]
# ## P1 deck: MidrangeBuffPaladin

# %%
v2.run_deck1_batch("MidrangeBuffPaladin")
# Out:
# ...
# V2 BATCH  deck1=MidrangeBuffPaladin  (4500 games: 5 P1 agents x 5 P2 agents x 9 decks x 20)
#   search depth=10 width=14   logs -> d:\test\log_v2
# ...
#
# ### aggro_MidrangeBuffPaladin  (900 games)
#   aggro    vs aggro   /MiraclePirateRogue       P1= 0 P2= 0 D=0 E=0 S=20  [   20/4500   0%]  eta   0.0 min  (0.0s)
#   aggro    vs aggro   /ZooDiscardWarlock        P1= 0 P2= 0 D=0 E=0 S=20  [   40/4500   1%]  eta   0.0 min  (0.0s)
#   aggro    vs aggro   /RenoKazakusDragonPriest  P1= 0 P2= 0 D=0 E=0 S=20  [   60/4500   1%]  eta   0.0 min  (0.0s)
#   aggro    vs aggro   /MidrangeSecretHunter     P1= 0 P2= 0 D=0 E=0 S=20  [   80/4500   2%]  eta   0.0 min  (0.0s)
#   aggro    vs aggro   /MidrangeBuffPaladin      P1= 0 P2= 0 D=0 E=0 S=20  [  100/4500   2%]  eta   0.0 min  (0.0s)
#   aggro    vs aggro   /MurlocDruid              P1= 0 P2= 0 D=0 E=0 S=20  [  120/4500   3%]  eta   0.0 min  (0.0s)
# ...

# %% [markdown]
# ## P1 deck: MurlocDruid

# %%
v2.run_deck1_batch("MurlocDruid")
# Out:
# ...
# V2 BATCH  deck1=MurlocDruid  (4500 games: 5 P1 agents x 5 P2 agents x 9 decks x 20)
#   search depth=10 width=14   logs -> d:\test\log_v2
# ...
#
# ### aggro_MurlocDruid  (900 games)
#   aggro    vs aggro   /MiraclePirateRogue       P1= 0 P2= 0 D=0 E=0 S=20  [   20/4500   0%]  eta   0.0 min  (0.0s)
#   aggro    vs aggro   /ZooDiscardWarlock        P1= 0 P2= 0 D=0 E=0 S=20  [   40/4500   1%]  eta   0.0 min  (0.0s)
#   aggro    vs aggro   /RenoKazakusDragonPriest  P1= 0 P2= 0 D=0 E=0 S=20  [   60/4500   1%]  eta   0.0 min  (0.0s)
#   aggro    vs aggro   /MidrangeSecretHunter     P1= 0 P2= 0 D=0 E=0 S=20  [   80/4500   2%]  eta   0.0 min  (0.0s)
#   aggro    vs aggro   /MidrangeBuffPaladin      P1= 0 P2= 0 D=0 E=0 S=20  [  100/4500   2%]  eta   0.0 min  (0.0s)
#   aggro    vs aggro   /MurlocDruid              P1= 0 P2= 0 D=0 E=0 S=20  [  120/4500   3%]  eta   0.0 min  (0.0s)
#   aggro    vs aggro   /MidrangeJadeShaman       P1= 0 P2= 0 D=0 E=0 S=20  [  140/4500   3%]  eta   0.0 min  (0.0s)
# ...

# %% [markdown]
# ## P1 deck: MidrangeJadeShaman

# %%
v2.run_deck1_batch("MidrangeJadeShaman")
# Out:
# ...
# V2 BATCH  deck1=MidrangeJadeShaman  (4500 games: 5 P1 agents x 5 P2 agents x 9 decks x 20)
#   search depth=10 width=14   logs -> d:\test\log_v2
# ...
#
# ### aggro_MidrangeJadeShaman  (900 games)
#   aggro    vs aggro   /MiraclePirateRogue       P1= 0 P2= 0 D=0 E=0 S=20  [   20/4500   0%]  eta   0.0 min  (0.0s)
#   aggro    vs aggro   /ZooDiscardWarlock        P1= 0 P2= 0 D=0 E=0 S=20  [   40/4500   1%]  eta   0.0 min  (0.0s)
#   aggro    vs aggro   /RenoKazakusDragonPriest  P1= 0 P2= 0 D=0 E=0 S=20  [   60/4500   1%]  eta   0.0 min  (0.0s)
#   aggro    vs aggro   /MidrangeSecretHunter     P1= 0 P2= 0 D=0 E=0 S=20  [   80/4500   2%]  eta   0.0 min  (0.0s)
#   aggro    vs aggro   /MidrangeBuffPaladin      P1= 0 P2= 0 D=0 E=0 S=20  [  100/4500   2%]  eta   0.0 min  (0.0s)
#   aggro    vs aggro   /MurlocDruid              P1= 0 P2= 0 D=0 E=0 S=20  [  120/4500   3%]  eta   0.0 min  (0.0s)
# ...

# %% [markdown]
# ## P1 deck: AggroPirateWarrior

# %%
v2.run_deck1_batch("AggroPirateWarrior")
# Out:
# ...
# V2 BATCH  deck1=AggroPirateWarrior  (4500 games: 5 P1 agents x 5 P2 agents x 9 decks x 20)
#   search depth=10 width=14   logs -> d:\test\log_v2
# ...
#
# ### aggro_AggroPirateWarrior  (900 games)
#   aggro    vs aggro   /MiraclePirateRogue       P1= 0 P2= 0 D=0 E=0 S=20  [   20/4500   0%]  eta   0.0 min  (0.0s)
#   aggro    vs aggro   /ZooDiscardWarlock        P1= 0 P2= 0 D=0 E=0 S=20  [   40/4500   1%]  eta   0.0 min  (0.0s)
#   aggro    vs aggro   /RenoKazakusDragonPriest  P1= 0 P2= 0 D=0 E=0 S=20  [   60/4500   1%]  eta   0.0 min  (0.0s)
#   aggro    vs aggro   /MidrangeSecretHunter     P1= 0 P2= 0 D=0 E=0 S=20  [   80/4500   2%]  eta   0.0 min  (0.0s)
#   aggro    vs aggro   /MidrangeBuffPaladin      P1= 0 P2= 0 D=0 E=0 S=20  [  100/4500   2%]  eta   0.0 min  (0.0s)
#   aggro    vs aggro   /MurlocDruid              P1= 0 P2= 0 D=0 E=0 S=20  [  120/4500   3%]  eta   0.0 min  (0.0s)
# ...

# %% [markdown]
# ## P1 deck: RenoKazakusMage

# %%
v2.run_deck1_batch("RenoKazakusMage")
# Out:
# ...
# V2 BATCH  deck1=RenoKazakusMage  (4500 games: 5 P1 agents x 5 P2 agents x 9 decks x 20)
#   search depth=10 width=14   logs -> d:\test\log_v2
# ...
#
# ### aggro_RenoKazakusMage  (900 games)
#   aggro    vs aggro   /MiraclePirateRogue       P1= 0 P2= 0 D=0 E=0 S=20  [   20/4500   0%]  eta   0.0 min  (0.0s)
#   aggro    vs aggro   /ZooDiscardWarlock        P1= 0 P2= 0 D=0 E=0 S=20  [   40/4500   1%]  eta   0.0 min  (0.0s)
#   aggro    vs aggro   /RenoKazakusDragonPriest  P1= 0 P2= 0 D=0 E=0 S=20  [   60/4500   1%]  eta   0.0 min  (0.0s)
#   aggro    vs aggro   /MidrangeSecretHunter     P1= 0 P2= 0 D=0 E=0 S=20  [   80/4500   2%]  eta   0.0 min  (0.0s)
#   aggro    vs aggro   /MidrangeBuffPaladin      P1= 0 P2= 0 D=0 E=0 S=20  [  100/4500   2%]  eta   0.0 min  (0.0s)
#   aggro    vs aggro   /MurlocDruid              P1= 0 P2= 1 D=0 E=0 S=19  [  120/4500   3%]  eta  45.8 min  (0.6s)
# ...

# %% [markdown]
# ## Progress overview
# Re-run anytime to see how far the batch has come.

# %%
import csv, glob, os
root = v2.DEFAULT_LOG_ROOT
total_done = total_err = 0
print("%-40s %8s %8s %8s" % ("directory", "games", "errors", "of 900"))
for sp in sorted(glob.glob(os.path.join(root, "*", "summary.csv"))):
    with open(sp, newline="", encoding="utf-8") as f:
        rows = list(csv.DictReader(f))
    err = sum(1 for r in rows if r["winner"] == "ERROR")
    ok = len(rows) - err
    total_done += ok; total_err += err
    print("%-40s %8d %8d %8s" % (os.path.basename(os.path.dirname(sp)), ok, err,
          "done" if ok >= 900 else ""))
print("\nTOTAL: %d games logged, %d errors  (target 40,500)" % (total_done, total_err))
# Out:
# directory                                   games   errors   of 900
# aggro_AggroPirateWarrior                      900        1     done
# aggro_MidrangeBuffPaladin                     900        0     done
# aggro_MidrangeJadeShaman                      900        1     done
# aggro_MidrangeSecretHunter                    900        0     done
# aggro_MiraclePirateRogue                      900        0     done
# aggro_MurlocDruid                             900        3     done
# aggro_RenoKazakusDragonPriest                 900        6     done
# aggro_RenoKazakusMage                         900        2     done
# aggro_ZooDiscardWarlock                       900        0     done
# control_AggroPirateWarrior                    900        1     done
# control_MidrangeBuffPaladin                   900        6     done
# control_MidrangeJadeShaman                    899        7
# control_MidrangeSecretHunter                  900        2     done
# ...
